# %%
# !pip install kaggle
# Out:
# ...
#     100% |████████████████████████████████| 61kB 7.3MB/s
# ...
#     100% |████████████████████████████████| 81kB 18.4MB/s
# ...
#   Stored in directory: /home/jupyter/.cache/pip/wheels/87/ea/09/173986e395d051411b9d547a69fe96cdc26208cb1bcc3e5567
# ...
#   Stored in directory: /home/jupyter/.cache/pip/wheels/16/7f/c3/6b0582283ad589d68a306da924a78c74546e010d8106b9b3a9
# Successfully built kaggle python-slugify
# ...

# %%
# !kaggle competitions download -c cifar-10 -p ./data/not_anime
# Out:
# ...
#   0%|                                               | 0.00/3.04M [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 3.04M/3.04M [00:00<00:00, 228MB/s]
# ...
#  98%|████████████████████████████████████████▎| 600M/610M [00:01<00:00, 396MB/s]
# 100%|█████████████████████████████████████████| 610M/610M [00:01<00:00, 389MB/s]
# ...
#  86%|██████████████████████████████████▍     | 90.0M/105M [00:00<00:00, 192MB/s]
# 100%|█████████████████████████████████████████| 105M/105M [00:00<00:00, 321MB/s]
# ...
#   0%|                                                | 0.00/575k [00:00<?, ?B/s]
# 100%|█████████████████████████████████████████| 575k/575k [00:00<00:00, 273MB/s]

# %%
# !pip install pyunpack
# !pip install patool
# Out:
# ...
#   Stored in directory: /home/jupyter/.cache/pip/wheels/af/44/08/60613970881e542c0baad1f2dea5ed8e6716bc573f49197b7e
# Successfully built pyunpack
# ...
#     100% |████████████████████████████████| 81kB 8.6MB/s
# ...

# %%
# !pip install libarchive
# Out:
# ...
#   Stored in directory: /home/jupyter/.cache/pip/wheels/3b/5c/fa/92ee330d259e8fa5bedbd53f67040710fe81cfa463b8711d26
# Successfully built libarchive
# ...

# %%
import subprocess

# %%
subprocess.call(["7z", "a", "./data/not_anime/test.7z", "*.*"])
# Out:
# 0

# %%
# !sudo apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   p7zip-rar
# The following NEW packages will be installed:
#   p7zip-full
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1,115 kB of archives.
# After this operation, 4,513 kB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian stretch/main amd64 p7zip-full amd64 16.02+dfsg-3+deb9u1 [1,115 kB]
# Fetched 1,115 kB in 0s (20.6 MB/s)
# Selecting previously unselected package p7zip-full.
# (Reading database ... 86011 files and directories currently installed.)
# Preparing to unpack .../p7zip-full_16.02+dfsg-3+deb9u1_amd64.deb ...
# Unpacking p7zip-full (16.02+dfsg-3+deb9u1) ...
# Setting up p7zip-full (16.02+dfsg-3+deb9u1) ...
# Processing triggers for man-db (2.7.6.1-2) ...

# %%
!7z x ./data/not_anime/test.7z -y
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,8 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
#   0M Scan ./data/not_anime                          1 file, 639443269 bytes (610 MiB)
#
# Extracting archive: ./data/not_anime/test.7z
# --
# Path = ./data/not_anime/test.7z
# Type = 7z
# Physical Size = 639443269
# Headers Size = 1721910
# Method = LZMA2:3m LZMA:26
# Solid = +
# Blocks = 2
#
# ...
