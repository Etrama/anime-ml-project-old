# %% [markdown]
# ## TO DO:
# - [-] Take rough number of images to be downloaded as input. (Rough because few images will be corrupt and deleted later on.) - MAY NOT NEED THIS, SEE BELOW. We could also gather URLS and then select the number of URLs to scrape. But this would cap the number of images at 100, since the script scrapes 100 URLS by default, not counting the few corrupt images that we'd lose.
# - [x] The make_image_dataset function should be able to take Lists as input. When taking list inputs, need to create folders within destination folder to segregate the images.

# %% [markdown]
# ## Getting more data:
# 1. Tagged Anime Illustrations: <br>
# https://www.kaggle.com/mylesoneill/tagged-anime-illustrations/home - Will need to clone this directly into GCP. 36 GB is too much for my pleb laptop.
#
# 2. Anime Faces : <br>
# http://www.nurs.or.jp/~nagadomi/animeface-character-dataset/
#
# 3. Check out the links above they lead to tabular anime data as well.

# %% [markdown]
# ### We can use this the dataset gathered for Anime Identification. That is, if the above falls short.

# %% [markdown]
# ## Lesson learnt:
# ## Save all FAST AI notebooks that you edit to your local storage.

# %%
#!pip install pyvirtualdisplay
#!pip install xvfbwrapper
#!sudo apt-get install xvfb

# %%
from imutils import paths
import argparse
import requests
import cv2
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import os
import glob
import time
from pyvirtualdisplay import Display
from threading import *
#import threading
from multiprocessing import Pool

# %%
#Anime_Faces_List =

# %%
images_to_download_list = ["naruto", "cowboy bebop"]

# %%
def make_image_dataset(image_name, lock, dest_folder = r"./trial", downloads_folder= r"/home/jupyter/Downloads/"):    
    #images_to_download = input("Which images do you want to download? ")
    #dest_folder = input("Where do you want the downloaded images? ")
    #downloads_folder = input("Enter the path to your downloads folder. ")
    
    os.mkdir(os.path.sep.join([dest_folder, image_name]))
    dest_folder_new = os.path.sep.join([dest_folder, image_name])
    
    #lock.acquire()
    options = webdriver.ChromeOptions()
    #options.add_argument('headless')
    #options.add_argument('window-size=1200x600')  
    display = Display(visible=0, size=(1200, 600))
    display.start()
        
    driver = webdriver.Chrome(executable_path = "/home/jupyter/chromedriver.exe", options=options)
    
    driver.get("https://www.google.com/search?tbm=isch&q=" + image_name)
    
    urls = driver.execute_script(r'''urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
    window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));''')
    time.sleep(4)
    
    driver.quit()
    display.stop()
    
    #list_of_files = glob.glob(r"C:\Users\kmoudgalya\Downloads\*") # * means all if need specific format then *.csv
    
    list_of_files = glob.glob(os.path.sep.join([downloads_folder, "/*"]))
    latest_file = max(list_of_files, key=lambda x: os.stat(x).st_mtime)
    #lock.release()
    
    rows = open(latest_file).read().strip().split("\n")
    total = 0
    
    
    # loop the URLs
    for url in rows:
        try:
            # try to download the image
            r = requests.get(url, timeout=10)

            # save the image to disk
            p = os.path.sep.join([dest_folder_new, "{}.jpg".format(str(total).zfill(8))])
            f = open(p, "wb")
            f.write(r.content)
            f.close()

            # update the counter
            print("[INFO] downloaded: {}".format(p))
            total += 1

        # handle if any exceptions are thrown during the download process
        except:
            print("[INFO] error downloading {}...skipping".format(p))
    
    
    # loop over the image paths we just downloaded
    for imagePath in paths.list_images(dest_folder_new):
        # initialize if the image should be deleted or not
        delete = False

        # try to load the image
        try:
            image = cv2.imread(imagePath)

            # if the image is `None` then we could not properly load it
            # from disk, so delete it
            if image is None:
                delete = True

        # if OpenCV cannot load the image then the image is likely
        # corrupt so we should delete it
        except:
            print("Except")
            delete = True

        # check to see if the image should be deleted
        if delete:
            print("[INFO] deleting {}".format(imagePath))
            os.remove(imagePath)
            
    #print("Images downloaded. Let the Machine Learning begin.")
    #lock.release()

# %%
# start_time = time.time()
# make_image_dataset("cowboy bepop")
# print('Entire job took:',time.time() - start_time)

# %%
# !rm /home/jupyter/Downloads/*
# !rm -r ./trial
# !mkdir ./trial

# %% [markdown]
# ### Time taken by function:
# #### Naruto images download      : 32.81 s <br>
# #### Cowboy Bepop images download: 40.70 s <br>
# #### Total time                  : 73.51 s <br>

# %%
start_time = time.time()
threadlist = []
for j in images_to_download_list:
    print(j)
    lock_1 = threading.Lock()
    t = Thread(target=make_image_dataset, args=(j,lock_1))
    
    t.start()
    threadlist.append(t)
    
for b in threadlist:
   b.join()
    
print('Entire job took:',time.time() - start_time)
# Out:
# naruto
# cowboy bebop
# [INFO] downloaded: ./trial/naruto/00000000.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000000.jpg
# [INFO] downloaded: ./trial/naruto/00000001.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000001.jpg
# [INFO] downloaded: ./trial/naruto/00000002.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000002.jpg
# [INFO] downloaded: ./trial/naruto/00000003.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000003.jpg
# [INFO] downloaded: ./trial/naruto/00000004.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000004.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000005.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000006.jpg
# [INFO] downloaded: ./trial/naruto/00000005.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000007.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000008.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000009.jpg
# [INFO] downloaded: ./trial/naruto/00000006.jpg
# [INFO] downloaded: ./trial/naruto/00000007.jpg
# [INFO] downloaded: ./trial/naruto/00000008.jpg
# [INFO] downloaded: ./trial/naruto/00000009.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000010.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000011.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000012.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000013.jpg
# [INFO] downloaded: ./trial/naruto/00000010.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000014.jpg
# [INFO] downloaded: ./trial/naruto/00000011.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000015.jpg
# [INFO] downloaded: ./trial/naruto/00000012.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000016.jpg
# [INFO] downloaded: ./trial/naruto/00000013.jpg
# [INFO] downloaded: ./trial/naruto/00000014.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000017.jpg
# [INFO] downloaded: ./trial/naruto/00000015.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000018.jpg
# [INFO] downloaded: ./trial/naruto/00000016.jpg
# [INFO] downloaded: ./trial/naruto/00000017.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000019.jpg
# [INFO] downloaded: ./trial/naruto/00000018.jpg
# [INFO] downloaded: ./trial/naruto/00000019.jpg
# [INFO] downloaded: ./trial/naruto/00000020.jpg
# [INFO] downloaded: ./trial/naruto/00000021.jpg
# [INFO] downloaded: ./trial/naruto/00000022.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000020.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000021.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000022.jpg
# [INFO] downloaded: ./trial/naruto/00000023.jpg
# [INFO] downloaded: ./trial/naruto/00000024.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000023.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000024.jpg
# [INFO] downloaded: ./trial/naruto/00000025.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000025.jpg
# [INFO] downloaded: ./trial/naruto/00000026.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000026.jpg
# [INFO] downloaded: ./trial/naruto/00000027.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000027.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00
jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000073.jpg
# [INFO] downloaded: ./trial/naruto/00000070.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000074.jpg
# [INFO] downloaded: ./trial/naruto/00000071.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000075.jpg
# [INFO] downloaded: ./trial/naruto/00000072.jpg
# [INFO] downloaded: ./trial/naruto/00000073.jpg
# [INFO] downloaded: ./trial/naruto/00000074.jpg
# [INFO] downloaded: ./trial/naruto/00000075.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000076.jpg
# [INFO] downloaded: ./trial/naruto/00000076.jpg
# [INFO] downloaded: ./trial/naruto/00000077.jpg
# [INFO] downloaded: ./trial/naruto/00000078.jpg
# [INFO] downloaded: ./trial/naruto/00000079.jpg
# [INFO] downloaded: ./trial/naruto/00000080.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000077.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000078.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000079.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000080.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000081.jpg
# [INFO] downloaded: ./trial/naruto/00000081.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000082.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000083.jpg
# [INFO] downloaded: ./trial/naruto/00000082.jpg
# [INFO] downloaded: ./trial/naruto/00000083.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000084.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000085.jpg
# [INFO] downloaded: ./trial/naruto/00000084.jpg
# [INFO] downloaded: ./trial/naruto/00000085.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000086.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000087.jpg
# [INFO] downloaded: ./trial/naruto/00000086.jpg
# [INFO] downloaded: ./trial/naruto/00000087.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000088.jpg
# [INFO] downloaded: ./trial/naruto/00000088.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000089.jpg
# [INFO] downloaded: ./trial/naruto/00000089.jpg
# [INFO] downloaded: ./trial/naruto/00000090.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000090.jpg
# [INFO] downloaded: ./trial/naruto/00000091.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000091.jpg
# [INFO] downloaded: ./trial/naruto/00000092.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000092.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000093.jpg
# [INFO] downloaded: ./trial/naruto/00000093.jpg
# [INFO] downloaded: ./trial/naruto/00000094.jpg
# [INFO] downloaded: ./trial/naruto/00000095.jpg
# [INFO] downloaded: ./trial/naruto/00000096.jpg
# [INFO] downloaded: ./trial/naruto/00000097.jpg
# [INFO] downloaded: ./trial/naruto/00000098.jpg
# [INFO] deleting ./trial/naruto/00000059.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000094.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000095.jpg
# [INFO] deleting ./trial/naruto/00000010.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000096.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000097.jpg
# [INFO] downloaded: ./trial/cowboy bebop/00000098.jpg
# [INFO] deleting ./trial/naruto/00000073.jpg
# [INFO] deleting ./trial/cowboy bebop/00000059.jpg
# [INFO] deleting ./trial/cowboy bebop/00000010.jpg
# [INFO] deleting ./trial/cowboy bebop/00000020.jpg
# [INFO] deleting ./trial/cowboy bebop/00000073.jpg
# Entire job took: 47.4556040763855

# %%
import os

# %%
list_of_files = glob.glob(os.path.sep.join([r"/home/jupyter/Downloads/", "/*"]))

# %%
list_of_files
# Out:
# ['/home/jupyter/Downloads/download (1)', '/home/jupyter/Downloads/download']

# %% [markdown]
# ### 24.05s (multi-threaded) vs 73.51s for the script to download images. I'd say this is a no brainer. 3x Improvement ftw! This is with 2 separate image targets (naruto and cowboy bepop).

# %% [markdown]
# ### The script simply pauses if one puts down the laptop lid and resumes when the user logs back in to the laptop. Phew.

# %% [markdown]
# ### 100x100 images (10000) take around 6-7 hours to be downloaded. Without Multithreading ofc.
